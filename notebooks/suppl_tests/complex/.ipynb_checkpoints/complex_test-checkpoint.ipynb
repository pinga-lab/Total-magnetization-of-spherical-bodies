# %% [markdown]
# # This notebook illustrates the performance of our method in recovering the magnetization direction of a synthetic body which simulates a complex geological scenario

# %%
#source1: https://neuronvisio.readthedocs.org/en/latest/gettingstarted.html#troubleshooting
#source2: http://ipython.org/ipython-doc/dev/interactive/reference.html#pyqt-and-pyside

import sip
sip.setapi('QString', 2)
sip.setapi('QVariant', 2)

# %%
# %matplotlib inline
import numpy as np
import scipy
from scipy import sparse, interpolate
from IPython.display import Image

from fatiando import mesher, gridder, gravmag
from fatiando.gravmag import sphere, polyprism, prism, fourier
from fatiando.gravmag.eqlayer import PELTotalField, PELSmoothness
from fatiando.inversion.regularization import LCurve
from fatiando.gravmag.euler import Classic, ExpandingWindow
from fatiando.utils import ang2vec, contaminate
from fatiando.vis import mpl, myv
from fatiando.gravmag.magdir import DipoleMagDir

# %% [markdown]
# ### This numerical test uses the open-source Python toolkit [Fatiando a Terra](http://fatiando.org/)

# %%
def uncertainty_L1(sigmad, solver):
    '''
    Calculate the uncertainty of the estimated
    intensities, inclinations and declinations
    obtained via L1 norm
    
    Parameters:
    
    * sigmad: float
        The uncertainty of the observed total field anomaly
        at all points.
    * solver: class:`fatiando.gravmag.magdir.DipoleMagDir`
        This class estimates the Cartesian components of the 
        magnetization vector of homogeneous dipolar bodies 
        with known center.

    Returns:
    
    * dh: list of arrays
        The uncertainties propagated from the observed data 
        to the estimated intensities, inclinations and 
        declinations of the magnetization vector of each 
        dipole.
    '''
    w = np.abs(solver.residuals())
    w[w < 10**(-10)] = 10**-10
    w = 1.0/w
    W = scipy.sparse.diags(w, 0)
    H = np.linalg.inv((solver.jacobian(p=None).T*W).dot(solver.jacobian(p=None))).dot(solver.jacobian(p=None).T)
    H = H*W
    dp = np.sqrt(np.diagonal((sigmad**2)*H.dot(H.T)))
    dp = np.reshape(dp, (solver.ndipoles, 3))
    dh = []
    dhj = np.zeros(3)
    pj = np.zeros(3)
    i = 0
    for pj in np.reshape(solver.p_, (solver.ndipoles, 3)):
        aux0 = pj[0]**2 + pj[1]**2
        aux1 = np.sqrt(aux0)
        aux2 = 1.0/aux0
        aux3 = 1.0/aux1
        aux4 = 1.0/solver.estimate_[i][0]
        dQx, dQy, dQz = (pj*aux4)
        dIx = pj[0]*(-pj[2]*(aux4**2)*aux3)
        dIy = pj[1]*(-pj[2]*(aux4**2)*aux3)
        dIz = aux1*(aux4**2)
        dDx = -pj[1]*aux2
        dDy = pj[0]*aux2
        dhj[0] = (dQx*dp[i][0])**2 + (dQy*dp[i][1])**2 + (dQz*dp[i][2])**2
        dhj[1] = (dIx*dp[i][0])**2 + (dIy*dp[i][1])**2 + (dIz*dp[i][2])**2
        dhj[2] = (dDx*dp[i][0])**2 + (dDy*dp[i][1])**2
        dhj = np.sqrt(dhj)
        dh.append(dhj)
        i = i+1
    return dh

def uncertainty_L2(sigmad, solver):
    '''
    Calculate the uncertainty of the estimated
    intensities, inclinations and declinations
    obtained via L2 norm
    
    Parameters:
    
    * sigmad: float
        The uncertainty of the observed total field anomaly
        at all points.
    * solver: class:`fatiando.gravmag.magdir.DipoleMagDir`
        This class estimates the Cartesian components of the 
        magnetization vector of homogeneous dipolar bodies 
        with known center.

    Returns:
    
    * dh: list of arrays
        The uncertainties propagated from the observed data 
        to the estimated intensities, inclinations and 
        declinations of the magnetization vector of each 
        dipole.
    '''
    dp = np.sqrt(np.diagonal((sigmad**2)*np.linalg.inv(solver.jacobian(p=None).T.dot(solver.jacobian(p=None)))))
    dp = np.reshape(dp, (solver.ndipoles, 3))
    dh = []
    dhj = np.zeros(3)
    pj = np.zeros(3)
    i = 0
    for pj in np.reshape(solver.p_, (solver.ndipoles, 3)):
        aux0 = pj[0]**2 + pj[1]**2
        aux1 = np.sqrt(aux0)
        aux2 = 1.0/aux0
        aux3 = 1.0/aux1
        aux4 = 1.0/solver.estimate_[i][0]
        dQx, dQy, dQz = (pj*aux4)
        dIx = pj[0]*(-pj[2]*(aux4**2)*aux3)
        dIy = pj[1]*(-pj[2]*(aux4**2)*aux3)
        dIz = aux1*(aux4**2)
        dDx = -pj[1]*aux2
        dDy = pj[0]*aux2
        dhj[0] = (dQx*dp[i][0])**2 + (dQy*dp[i][1])**2 + (dQz*dp[i][2])**2
        dhj[1] = (dIx*dp[i][0])**2 + (dIy*dp[i][1])**2 + (dIz*dp[i][2])**2
        dhj[2] = (dDx*dp[i][0])**2 + (dDy*dp[i][1])**2
        dhj = np.sqrt(dhj)
        dh.append(dhj)
        i = i+1
    return dh

# %% [markdown]
# ### The magnetic data are calculated over an area with dimensions of:

# %%
area = [0, 10000, 45000, 55000]
bounds = area + [0, 5000]

# %% [markdown]
# ### Regular data grid calculated at a constant plane with vertical coordinate $z = -800 \, m$

# %%
shape = (100,100)
z0 = -800
x, y, z = gridder.regular(area, shape, z=z0)

# %% [markdown]
# ### Regular data profile calculated at the constant plane with vertical coordinate $z = -800 \, m$

# %%
yminb = 0
ymaxb = 100000.0
ny = 201
dy = (ymaxb - yminb)/(ny - 1)
L = ymaxb - yminb
yb = np.linspace(yminb, ymaxb, ny)
zb = np.zeros_like(yb)+z0

zminb = 0.0
zmaxb = 5000.0
xminb = -100000.0
xmaxb =  100000.0

areab = [yminb, ymaxb, zmaxb, zminb]

# %% [markdown]
# ### Direction of the Geomagnetic Field

# %%
inc, dec = -39.8, -22.5 # inclination and declination of the Geomagnetic Field

# %% [markdown]
# ### Synthetic igneous intrusion formed by a sill which is fed by a vertical pipe. This intrusive body is emplaced in weakly magnetized sediments.

# %%
incs = -inc # inclination of the sources (reversed)
decs = dec+180 # declination of the sources (reversed)
ints = 6.0   # intensity of the sources

print 'X Y Z components of the geomagnetic field (versor)'
print ang2vec(1.0,inc,dec)
print 'X Y Z components of the intrusion magnetization (versor)'
print ang2vec(1.0,incs,decs)
# Out:
# X Y Z components of the geomagnetic field (versor)
# [ 0.70980142 -0.29400938 -0.6401097 ]
# X Y Z components of the intrusion magnetization (versor)
# [-0.70980142  0.29400938  0.6401097 ]

# %%
# Synthetic intrusion
depths = [200, 400, 5000]

vertices_sill = [[  7248.9539749 ,  49712.34309623],
                    [  6961.29707113,  50836.82008368],
                    [  6542.88702929,  51359.83263598],
                    [  5889.12133891,  51804.39330544],
                    [  5130.75313808,  52196.65271967],
                    [  4424.68619247,  52170.50209205],
                    [  3692.46861925,  51699.79079498],
                    [  3483.26359833,  50915.27196653],
                    [  3404.81171548,  50000.        ],
                    [  3352.51046025,  48980.12552301],
                    [  3640.16736402,  47881.79916318],
                    [  4424.68619247,  47201.88284519],
                    [  5104.60251046,  47228.0334728 ],
                    [  5810.66945607,  47646.44351464],
                    [  6333.68200837,  48274.05857741],
                    [  6647.48953975,  48718.61924686],
                    [  7092.05020921,  49215.48117155]]

vertices_pipe = [[  5444.56066946,  49869.24686192],
                 [  5287.65690377,  50000.        ],
                 [  5156.90376569,  49869.24686192],
                 [  5287.65690377,  49633.89121339],
                 [  5392.25941423,  49712.34309623]]

model = [mesher.PolygonalPrism(vertices_sill, depths[0], depths[1], 
                              {'magnetization': ang2vec(ints, incs, decs)}),
         mesher.PolygonalPrism(vertices_pipe, depths[1], depths[2], 
                              {'magnetization': ang2vec(ints, incs, decs)})]

modelpole = [mesher.PolygonalPrism(vertices_sill, depths[0], depths[1], 
                                  {'magnetization': ang2vec(ints, -90.0, decs)}),
             mesher.PolygonalPrism(vertices_pipe, depths[1], depths[2], 
                                  {'magnetization': ang2vec(ints, -90.0, decs)})]

# %%
# Create a synthetic intrusion interactively
#depths = [200, 400, 5000]
#model = []

#mpl.close('all')
#axes = mpl.figure().gca()
#mpl.axis('scaled')
#for p in model:
#    mpl.polygon(p, '.-k', xy2ne=True)
#vertices_sill = mpl.draw_polygon(area, axes, xy2ne=True)
#model.append(
#    mesher.PolygonalPrism(vertices_sill, depths[0], depths[1], 
#                          {'magnetization': ints}))
#mpl.close('all')
#axes = mpl.figure().gca()
#mpl.axis('scaled')
#for p in model:
#    mpl.polygon(p, '.-k', xy2ne=True)
#vertices_pipe = mpl.draw_polygon(area, axes, xy2ne=True)
#model.append(
#    mesher.PolygonalPrism(vertices_pipe, depths[1], depths[2], 
#                          {'magnetization': ints}))
#vertices_sill, vertices_pipe

# %%
# Parameters of the pipe
xpipe = 0.5*(np.max(model[1].x) + np.min(model[1].x))
xb = np.zeros_like(yb)+xpipe
ypipe = 0.5*(np.max(model[1].y) + np.min(model[1].y))
Lpipe = np.max(model[1].y) - np.min(model[1].y)

# Parameters of the sill
ysill = 0.5*(np.max(model[0].y) + np.min(model[0].y))
Lsilly = np.max(model[0].y) - np.min(model[0].y)
Lsillz = depths[1]-depths[0]

# Pipe
pipe_polygon = mesher.Polygon([[ypipe - 0.5*Lpipe, depths[1]], 
                               [ypipe + 0.5*Lpipe, depths[1]], 
                               [ypipe + 0.5*Lpipe, depths[2]],
                               [ypipe - 0.5*Lpipe, depths[2]]])
# Sill
sill_polygon = mesher.Polygon([[ysill - 0.5*Lsilly, depths[0]], 
                               [ysill + 0.5*Lsilly, depths[0]], 
                               [ysill + 0.5*Lsilly, depths[1]],
                               [ysill - 0.5*Lsilly, depths[1]]])

# %%
# Plot the model
scene = myv.figure(size=(1000, 800))
myv.polyprisms(model, 'magnetization')
ax = myv.axes(myv.outline(extent=bounds), ranges=[b*0.001 for b in bounds], nlabels=3, fmt='%.1f')
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x(km)', 'y(km)', 'z(km)'
ax.axes.font_factor = 1.2
myv.wall_north(bounds)
myv.wall_bottom(bounds)
scene.scene.camera.position = [-19421.972597682194, 38604.500728965533, -8149.9428404520268]
scene.scene.camera.focal_point = [5000.0, 50000.0, 2500.0]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.33902553145737457, 0.1425067701283754, -0.9299212383248503]
scene.scene.camera.clipping_range = [14561.056179714791, 47195.349378834064]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()
myv.savefig('intrusion.png')
myv.show()
Image(filename='intrusion.png')
# Out:
# WARNING:traits.has_traits:DEPRECATED: traits.has_traits.wrapped_class, 'the 'implements' class advisor has been deprecated. Use the 'provides' class decorator.

# %% [markdown]
# ### Total field anomaly (TFA) produced by the synthetic intrusion shown above

# %%
tf_intrusion = polyprism.tf(x, y, z, model, inc, dec)
tf_intrusion_profile = polyprism.tf(xb, yb, zb, model, inc, dec)

# %% [markdown]
# ### 2D plot of the intrusion and its TFA

# %%
mpl.close('all')
mpl.figure(figsize=(10, 6))

lambida = 0.10

mpl.subplot(2,1,1)
mpl.title('Intrusion TFA', fontsize=20)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.plot(0.001*yb, tf_intrusion_profile, 'r-')
mpl.plot(0.001*yb, tf_intrusion_profile, 'ro', markersize=3)
vmax = np.max(tf_intrusion_profile)
vmin = np.min(tf_intrusion_profile)
dv = lambida*(vmax - vmin)
mpl.ylim(vmin - dv, vmax + dv)
mpl.xlim(0.001*yminb, 0.001*ymaxb)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.ylabel('TFA (nT)', fontsize=18)

mpl.subplot(2,1,2)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.paths([[yminb, z0]], [[ymaxb, z0]], style='-b', linewidth=2, 
          label='data profile')
mpl.polygon(pipe_polygon, style='-k', linewidth=1)
mpl.polygon(sill_polygon, style='-k', linewidth=1)
dv = lambida*(zmaxb - zminb)
mpl.ylim(zmaxb, z0 - dv)
mpl.xlim(yminb, ymaxb)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.xlabel('y (km)', fontsize=18)
mpl.ylabel('z (km)', fontsize=18)
mpl.legend(loc='best', fontsize=18)
mpl.m2km()
mpl.savefig('intrusion2D.png', dpi=600)
#Image(filename='intrusion2D.png')

# %% [markdown]
# ### Synthetic basement underneath the weakly-magnetized sediments. This synthetic basement is infinite along the x-axis.

# %%
basement_polygon = []
basement = []

nb = 201

by = np.array([      0.,     500.,    1000.,    1500.,    2000.,    2500.,
                   3000.,    3500.,    4000.,    4500.,    5000.,    5500.,
                   6000.,    6500.,    7000.,    7500.,    8000.,    8500.,
                   9000.,    9500.,   10000.,   10500.,   11000.,   11500.,
                  12000.,   12500.,   13000.,   13500.,   14000.,   14500.,
                  15000.,   15500.,   16000.,   16500.,   17000.,   17500.,
                  18000.,   18500.,   19000.,   19500.,   20000.,   20500.,
                  21000.,   21500.,   22000.,   22500.,   23000.,   23500.,
                  24000.,   24500.,   25000.,   25500.,   26000.,   26500.,
                  27000.,   27500.,   28000.,   28500.,   29000.,   29500.,
                  30000.,   30500.,   31000.,   31500.,   32000.,   32500.,
                  33000.,   33500.,   34000.,   34500.,   35000.,   35500.,
                  36000.,   36500.,   37000.,   37500.,   38000.,   38500.,
                  39000.,   39500.,   40000.,   40500.,   41000.,   41500.,
                  42000.,   42500.,   43000.,   43500.,   44000.,   44500.,
                  45000.,   45500.,   46000.,   46500.,   47000.,   47500.,
                  48000.,   48500.,   49000.,   49500.,   50000.,   50500.,
                  51000.,   51500.,   52000.,   52500.,   53000.,   53500.,
                  54000.,   54500.,   55000.,   55500.,   56000.,   56500.,
                  57000.,   57500.,   58000.,   58500.,   59000.,   59500.,
                  60000.,   60500.,   61000.,   61500.,   62000.,   62500.,
                  63000.,   63500.,   64000.,   64500.,   65000.,   65500.,
                  66000.,   66500.,   67000.,   67500.,   68000.,   68500.,
                  69000.,   69500.,   70000.,   70500.,   71000.,   71500.,
                  72000.,   72500.,   73000.,   73500.,   74000.,   74500.,
                  75000.,   75500.,   76000.,   76500.,   77000.,   77500.,
                  78000.,   78500.,   79000.,   79500.,   80000.,   80500.,
                  81000.,   81500.,   82000.,   82500.,   83000.,   83500.,
                  84000.,   84500.,   85000.,   85500.,   86000.,   86500.,
                  87000.,   87500.,   88000.,   88500.,   89000.,   89500.,
                  90000.,   90500.,   91000.,   91500.,   92000.,   92500.,
                  93000.,   93500.,   94000.,   94500.,   95000.,   95500.,
                  96000.,   96500.,   97000.,   97500.,   98000.,   98500.,
                  99000.,   99500.,  100000.])

bz = np.array([    0.        ,   124.47589099,   243.79258386,   363.10927673,
                  482.4259696 ,   601.74266247,   721.05935535,   840.37604822,
                  959.69274109,  1036.12485823,  1100.04897412,  1163.97309001,
                 1227.8972059 ,  1291.82132179,  1355.74543767,  1419.66955356,
                 1483.59366945,  1547.51778534,  1611.44190123,  1621.98821862,
                 1628.85330853,  1635.71839844,  1642.58348835,  1649.44857826,
                 1656.31366817,  1663.17875808,  1670.04384799,  1676.9089379 ,
                 1683.77402781,  1690.63911773,  1688.42997392,  1676.54164749,
                 1664.65332106,  1652.76499463,  1640.8766682 ,  1628.98834177,
                 1617.10001534,  1605.21168891,  1593.32336248,  1581.43503605,
                 1569.54670962,  1557.65838319,  1545.77005676,  1566.29979036,
                 1680.03144654,  1793.76310273,  1907.49475891,  2021.22641509,
                 2134.95807128,  2248.68972746,  2362.42138365,  2476.15303983,
                 2589.88469602,  2703.6163522 ,  2817.34800839,  2924.39118034,
                 2996.65423431,  3068.91728828,  3141.18034226,  3213.44339623,
                 3285.7064502 ,  3357.96950417,  3430.23255814,  3502.49561211,
                 3574.75866608,  3647.02172005,  3719.28477402,  3791.54782799,
                 3863.81088197,  3930.31483107,  3982.74096826,  4035.16710546,
                 4087.59324265,  4140.01937984,  4192.44551704,  4244.87165423,
                 4297.29779143,  4349.72392862,  4402.15006582,  4454.57620301,
                 4507.00234021,  4559.4284774 ,  4611.8546146 ,  4648.6831761 ,
                 4663.91509434,  4679.14701258,  4694.37893082,  4709.61084906,
                 4724.8427673 ,  4740.07468553,  4755.30660377,  4770.53852201,
                 4785.77044025,  4801.00235849,  4816.23427673,  4831.46619497,
                 4846.69811321,  4849.49504112,  4809.6577165 ,  4769.82039187,
                 4729.98306725,  4690.14574262,  4650.308418  ,  4610.47109337,
                 4570.63376875,  4530.79644412,  4452.95332272,  4367.80139426,
                 4282.64946579,  4197.49753732,  4112.34560885,  4027.19368038,
                 3942.04175191,  3856.88982344,  3771.73789498,  3686.58596651,
                 3601.43403804,  3516.28210957,  3431.1301811 ,  3418.14072327,
                 3492.77712264,  3567.41352201,  3642.04992138,  3716.68632075,
                 3791.32272013,  3865.9591195 ,  3940.59551887,  4015.23191824,
                 4089.86831761,  4164.50471698,  4239.14111635,  4313.77751572,
                 4366.44781574,  4401.02838688,  4435.60895801,  4470.18952915,
                 4504.77010029,  4539.35067143,  4573.93124256,  4608.5118137 ,
                 4643.09238484,  4677.67295597,  4712.25352711,  4746.83409825,
                 4758.52272727,  4755.75328759,  4752.98384791,  4750.21440823,
                 4747.44496855,  4744.67552887,  4741.90608919,  4739.13664951,
                 4736.36720983,  4733.59777015,  4730.82833047,  4728.05889079,
                 4725.28945111,  4722.52001144,  4704.94300314,  4666.86320755,
                 4628.78341195,  4590.70361635,  4552.62382075,  4514.54402516,
                 4476.46422956,  4438.38443396,  4400.30463836,  4362.22484277,
                 4324.14504717,  4286.06525157,  4247.98545597,  4177.60459393,
                 4076.94148209,  3976.27837025,  3875.61525841,  3774.95214657,
                 3674.28903473,  3573.62592289,  3457.06863549,  3192.1657096 ,
                 2927.2627837 ,  2662.35985781,  2405.66037736,  2161.94968553,
                 1918.23899371,  1674.52830189,  1470.0343718 ,  1336.84364487,
                 1203.65291795,  1070.46219102,   937.27146409,   804.08073717,
                  670.89001024,   557.93786926,   473.00838574,   388.07890223,
                  303.14941872,   218.2199352 ,     0.        ,     0.        ,
                    0.        ])

basement_polygon = mesher.Polygon(np.vstack((by, bz)).T)

# 2D Plot of the basement
mpl.close('all')
mpl.figure(figsize=(15, 4))
mpl.axis('auto')
mpl.title('Basement (infinite along the x-axis)', fontsize=20)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.polygon(basement_polygon, style='--k', linewidth=1)
mpl.ylim(zmaxb, zminb)
mpl.xlim(yminb, ymaxb)
mpl.xlabel('y (km)', fontsize=18)
mpl.ylabel('z (km)', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.m2km()
#mpl.show()

# List of prisms forming the basement
db = (ymaxb - yminb)/(nb - 1)
for i in range(nb):
    basement.append(mesher.Prism(-100000, 100000, 
                                 by[i], by[i] + db,
                                 0.0, bz[i], {'magnetization': -0.1}))

# %%
# Create a synthetic basement interactively
#basement_polygon = []
#basement = []

# Initial basement
#mpl.close('all')
#axes = mpl.pyplot.figure(figsize=(20,4)).add_subplot(1,1,1)
#mpl.axis('auto')
#mpl.ylim(zmaxb, zminb)
#mpl.xlim(yminb, ymaxb)
#mpl.xlabel('y (m)')
#mpl.ylabel('z (m)')
#mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
#mpl.polygon(pipe_polygon, style='-k', linewidth=1)
#mpl.polygon(sill_polygon, style='-k', linewidth=1)
#d = mpl.draw_polygon(areab, axes, color='r')

# Interpolated basement
#f = interpolate.interp1d(d[:,0], d[:,1], kind = 'linear', bounds_error = False, fill_value = 0.0)
#nb = 201
#by = np.linspace(yminb, ymaxb, nb)
#bz = f(by)
#bz[0] = 0.0
#bz[nb-1] = 0.0

#basement_polygon = mesher.Polygon(np.vstack((by, bz)).T)

# 2D Plot of the basement
#mpl.close('all')
#mpl.figure()
#mpl.axis('auto')
#mpl.title('Basement')
#mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
#mpl.polygon(basement_polygon, style='--k', linewidth=1)
#mpl.ylim(zmaxb, zminb)
#mpl.xlim(yminb, ymaxb)
#mpl.xlabel('y (km)')
#mpl.ylabel('z (km)')
#mpl.m2km()
#mpl.show()

# List of prisms forming the basement
#db = (ymaxb - yminb)/(nb - 1)
#for i in range(nb):
#    basement.append(mesher.Prism(-100000, 100000, 
#                                 by[i], by[i] + db,
#                                 0.0, bz[i], {'magnetization': -0.1}))

#by, bz

# %% [markdown]
# ### Total field anomaly (TFA) produced by the synthetic basement underneath weakly-magnetized sediments

# %%
tf_basement = prism.tf(x, y, z, basement, inc, dec)
tf_basement_profile = prism.tf(xb, yb, zb, basement, inc, dec)

# %% [markdown]
# ### 2D plot of the basement and its TFA

# %%
mpl.close('all')
mpl.figure(figsize=(10, 6))

lambida = 0.10

mpl.subplot(2,1,1)
mpl.title('Basement TFA', fontsize=20)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.plot(0.001*yb, tf_basement_profile, 'r-')
mpl.plot(0.001*yb, tf_basement_profile, 'ro', markersize=3)
vmax = np.max(tf_basement_profile)
vmin = np.min(tf_basement_profile)
dv = lambida*(vmax - vmin)
mpl.ylim(vmin - dv, vmax + dv)
mpl.xlim(0.001*yminb, 0.001*ymaxb)
mpl.ylabel('TFA (nT)', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)

mpl.subplot(2,1,2)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.paths([[yminb, z0]], [[ymaxb, z0]], style='-b', linewidth=2,
          label='data profile')
mpl.polygon(basement_polygon, style='--k', linewidth=1)
dv = lambida*(zmaxb - zminb)
mpl.ylim(zmaxb, z0 - dv)
mpl.xlim(yminb, ymaxb)
mpl.xlabel('y (km)', fontsize=18)
mpl.ylabel('z (km)', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.legend(loc='lower left', fontsize=18)
mpl.m2km()
mpl.savefig('basement.png', dpi=600)
#Image(filename='basement.png')

# %% [markdown]
# ### Total field anomaly (TFA) produced by the intrusion and the basement on the data profile

# %%
tf_profile = tf_intrusion_profile + tf_basement_profile   

# Plot the intrusion + basement + total field anomaly
lambida = 0.10
mpl.close('all')
mpl.figure(figsize=(10, 6))

mpl.subplot(2,1,1)
mpl.title('Intrusion+Basement TFA', fontsize=20)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.plot(0.001*yb, tf_profile, 'r-')
mpl.plot(0.001*yb, tf_profile, 'ro', markersize=3)
vmax = np.max(tf_profile)
vmin = np.min(tf_profile)
dv = lambida*(vmax - vmin)
mpl.ylim(vmin - dv, vmax + dv)
mpl.xlim(0.001*yminb, 0.001*ymaxb)
mpl.ylabel('TFA (nT)', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)

mpl.subplot(2,1,2)
mpl.paths([[yminb, 0.0]], [[ymaxb, 0.0]], style='-k', linewidth=1)
mpl.paths([[yminb, z0]], [[ymaxb, z0]], style='-b', linewidth=2,
          label='data profile')
mpl.polygon(basement_polygon, style='--k', linewidth=1)
mpl.polygon(pipe_polygon, style='-k', linewidth=1)
mpl.polygon(sill_polygon, style='-k', linewidth=1)
dv = lambida*(zmaxb - zminb)
mpl.ylim(zmaxb, z0 - dv)
mpl.xlim(yminb, ymaxb)
mpl.xlabel('y (km)', fontsize=18)
mpl.ylabel('z (km)', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.legend(loc='lower left', fontsize=18)
mpl.m2km()
mpl.savefig('intrusion+basement.png', dpi=600)
#Image(filename='intrusion+basement.png')

# %% [markdown]
# ### Noise-corrupted total field anomaly (NCTFA) produced by the synthetic intrusion and the synthetic basement on the data grid

# %%
tf = tf_intrusion + tf_basement

# %%
# Total field anomaly contaminated with Gaussian noise with zero 
# mean and standard deviation uncertainty_data
uncertainty_data = 2.0 # nT
tf = contaminate(tf, uncertainty_data)

# %%
# Plot the data
mpl.close("all")
mpl.figure(figsize = (8, 8), tight_layout = True)
mpl.axis('scaled')
mpl.title('Intrusion+Basement NCTFA (nT)', fontsize=20)
mpl.contourf(y, x, tf, (50,50), 30, interp=True, extrapolate=True)
mpl.xlabel('y (km)', fontsize = 16)
mpl.ylabel('x (km)', fontsize = 16)
mpl.xticks(fontsize = 14)
mpl.yticks(fontsize = 14)
mpl.colorbar(shrink=0.75)
mpl.m2km()
mpl.savefig('NCTFA.png', dpi=600)
#Image(filename='TFA.png')
# Out:
# c:\Anaconda\lib\site-packages\matplotlib\figure.py:1644: UserWarning: This figure includes Axes that are not compatible with tight_layout, so its results might be incorrect.
#   warnings.warn("This figure includes Axes that are not "

# %% [markdown]
# ### Estimation of the position of the intrusion via Euler Deconvolution. The position of the intrusion is estimated by using an Euler Deconvolution with [expanding window strategy](http://fatiando.readthedocs.org/en/latest/api/gravmag.euler.html#fatiando.gravmag.euler.ExpandingWindow). The Euler Deconvolution is applied to the noise-corrupted total field anomaly (NCTFA) produced by the intrusion + basement on the data grid. *The synthetic intrusion is not an ideal source and does not have a characteristic structural index*. In this case, we consider that the NCTFA is produced by a dipole and use a structural index equal to 3.

# %%
# Calculate the derivatives using FFT
xderiv = fourier.derivx(x, y, tf, shape)
yderiv = fourier.derivy(x, y, tf, shape)
zderiv = fourier.derivz(x, y, tf, shape)

# Pick the centers of the expanding windows
# The number of final solutions will be the number of points picked
#axes = mpl.figure().add_subplot(1,1,1)
#mpl.suptitle('Pick the centers of the expanding windows')
#mpl.axis('scaled')
#mpl.contourf(y, x, tf, shape, 50)
#mpl.colorbar()
#mpl.xlabel('y (m)')
#mpl.ylabel('x (m)')
#centersw = mpl.pick_points(area, mpl.gca(), xy2ne=True)

centersw = [[  5052.30125523,  49670.50209205]]

# %%
# Run the euler deconvolution on an expanding window
# Structural index is 3
euler = Classic(x, y, z, tf, xderiv, yderiv, zderiv, 3)
sizes = np.linspace(500, 7000, 20)
results = [ExpandingWindow(euler, cw, sizes).fit() for cw in centersw]
centers = []
for i, r in enumerate(results):
    centers.append(r.estimate_)

# %% [markdown]
# ### Synthetic intrusion (in blue) and the estimated position of the *center* of the source (black point)

# %%
scene = myv.figure(size=(1000, 800))
myv.polyprisms(model, 'magnetization', opacity=0.3)
myv.points(centers, color=(0, 0, 0), size=200.0)
ax = myv.axes(myv.outline(extent=bounds), ranges=[b*0.001 for b in bounds], nlabels=3, fmt='%.1f')
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x(km)', 'y(km)', 'z(km)'
ax.axes.font_factor = 1.2
myv.wall_north(bounds)
myv.wall_bottom(bounds)
scene.scene.camera.position = [-19421.972597682194, 38604.500728965533, -8149.9428404520268]
scene.scene.camera.focal_point = [5000.0, 50000.0, 2500.0]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.33902553145737457, 0.1425067701283754, -0.9299212383248503]
scene.scene.camera.clipping_range = [14561.056179714791, 47195.349378834064]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()
myv.savefig('intrusion+estcenter.png')
myv.show()
Image(filename='intrusion+estcenter.png')

# %%
scene = myv.figure(size=(1000, 800))
myv.polyprisms(model, 'magnetization', opacity=0.3)
myv.points(centers, color=(0, 0, 0), size=200.0)
ax = myv.axes(myv.outline(extent=bounds), ranges=[b*0.001 for b in bounds], nlabels=3, fmt='%.1f')
ax.axes.x_label, ax.axes.y_label, ax.axes.z_label = 'x(km)', 'y(km)', 'z(km)'
ax.axes.font_factor = 1.2
myv.wall_north(bounds)
myv.wall_bottom(bounds)
scene.scene.camera.position = [-13876.415247715013, 71877.883405675486, 320.41362032638312]
scene.scene.camera.focal_point = [5000.0000000000209, 49999.999999999869, 2499.9999999999955]
scene.scene.camera.view_angle = 30.0
scene.scene.camera.view_up = [0.05147657480232995, -0.054928011371753162, -0.99716251223828367]
scene.scene.camera.clipping_range = [14320.133501349588, 47498.621393559122]
scene.scene.camera.compute_view_plane_normal()
scene.scene.render()
myv.savefig('intrusion+estcenter2.png')
myv.show()
Image(filename='intrusion+estcenter2.png')

# %% [markdown]
# ### Estimation of the magnetization direction of the synthetic intrusion by using the estimated position of the *center* of the source shown above.

# %%
#L2-norm estimate
solver_L2 = DipoleMagDir(x, y, z, tf, inc, dec, centers).fit()

# L1-norm estimate
solver_L1 = DipoleMagDir(x, y, z, tf, inc, dec, centers).fit()
for i in range(100):
    w = np.abs(solver_L1.residuals())
    w[w < 10**(-10)] = 10**-10
    w = 1/w
    solver_L1.set_weights(w)
    solver_L1.fit()

# Calculate the uncertainties
dh_L2 = uncertainty_L2(uncertainty_data, solver_L2)
dh_L1 = uncertainty_L1(uncertainty_data, solver_L1)

# Print the estimated and true inclinations and declinations
print 'Comparison between the true and estimated parameters'
print 'inclination (first colunm) and declination (second colunm)'
print 'True'
for i in range(solver_L1.ndipoles):
    print '%12.5f %12.5f' % (incs, decs)
print 'Estimated L2'
for e in solver_L2.estimate_:
    print '%12.5f %12.5f' % (e[1], e[2])
print 'Uncertainties L2'
for dhj in dh_L2:
    print '%12.5f %12.5f' % (dhj[1], dhj[2])
print 'Estimated L1'
for e in solver_L1.estimate_:
    print '%12.5f %12.5f' % (e[1], e[2])
print 'Uncertainties L1'
for dhj in dh_L1:
    print '%12.5f %12.5f' % (dhj[1], dhj[2])
# Out:
# Comparison between the true and estimated parameters
# inclination (first colunm) and declination (second colunm)
# True
#     39.80000    157.50000
# Estimated L2
#     36.89124    167.98439
# Uncertainties L2
#      0.00035      0.00059
# Estimated L1
#     39.42679    164.84797
# Uncertainties L1
#      0.01379      0.03073

# %%
hg = np.sqrt((np.cos(np.deg2rad(inc))*np.cos(np.deg2rad(dec)))**2 + \
             (np.cos(np.deg2rad(inc))*np.sin(np.deg2rad(dec)))**2)
ht = np.sqrt((np.cos(np.deg2rad(incs))*np.cos(np.deg2rad(decs)))**2 + \
             (np.cos(np.deg2rad(incs))*np.sin(np.deg2rad(decs)))**2)

mpl.figure(figsize=(8,8))
ax = mpl.subplot(111, polar=True)
ax.set_theta_direction(-1)
ax.set_theta_zero_location('N')
ax.set_rgrids([0.2,0.4,0.6,0.8], angle=90.)
# direction of the Geomagnetic field
if inc >= 0.0:
    mpl.plot(np.deg2rad(dec), hg, marker='^', ms=14, 
             mec='k', mew=3, mfc='k', fillstyle='full')
else:
    mpl.plot(np.deg2rad(dec), hg, marker='^', ms=14, 
             mec='k', mew=3, fillstyle='none')
# true magnetization direction
if incs >= 0.0:
    mpl.plot(np.deg2rad(decs), ht, marker='o', ms=10, 
             mec='k', mew=3, mfc='k', fillstyle='full')
else:
    mpl.plot(np.deg2rad(decs), ht, marker='o', ms=10, 
             mec='k', mew=3, fillstyle='none')
# L2-norm estimates
for e in solver_L2.estimate_:
    he = np.sqrt((np.cos(np.deg2rad(e[1]))*np.cos(np.deg2rad(e[2])))**2 + \
                 (np.cos(np.deg2rad(e[1]))*np.sin(np.deg2rad(e[2])))**2)
    if e[1] >= 0.0:
        mpl.plot(np.deg2rad(decs), he, marker='x', ms=10, 
             mec='b', mew=3, mfc='b', fillstyle='full')
    else:
        mpl.plot(np.deg2rad(decs), he, marker='x', ms=10, 
             mec='b', mew=3, fillstyle='none')
# L1-norm estimates
for e in solver_L1.estimate_:
    he = np.sqrt((np.cos(np.deg2rad(e[1]))*np.cos(np.deg2rad(e[2])))**2 + \
                 (np.cos(np.deg2rad(e[1]))*np.sin(np.deg2rad(e[2])))**2)
    if e[1] >= 0.0:
        mpl.plot(np.deg2rad(decs), he, marker='+', ms=12, 
             mec='r', mew=3, mfc='r', fillstyle='full')
    else:
        mpl.plot(np.deg2rad(decs), he, marker='+', ms=12, 
             mec='r', mew=3, fillstyle='none')#c.set_alpha(1.0)
mpl.xticks(fontsize=20) # on the cicle
mpl.yticks(fontsize=14) # along the radial direction
mpl.ylim(0.0, 1.0)
mpl.show()

# %% [markdown]
# ### Data fit obtained via the least-squares and robust approaches

# %%
mpl.close("all")
mpl.figure(figsize=(14, 5), tight_layout = True)
mpl.subplot(1, 2, 1)
mpl.title("L2-norm approach", fontsize = 20)
mpl.axis('scaled')
nlevels = mpl.contour(y, x, tf, (50,50), 15, interp=True, color='r', label='Observed', 
            clabel=True, style='solid', linewidth=2.0)
mpl.contour(y, x, solver_L2.predicted(), (50,50), nlevels, interp=True, color='b', label='Predicted', 
            clabel=True, style='dashed', linewidth=2.0)
mpl.legend(loc='best', shadow=True, prop={'size':16})
mpl.xlabel('y (km)', fontsize = 16)
mpl.ylabel('x (km)', fontsize = 16)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.subplot(1, 2, 2)
mpl.title("L1-norm approach", fontsize = 20)
mpl.axis('scaled')
nlevels = mpl.contour(y, x, tf, (50,50), 15, interp=True, color='r', label='Observed', 
            clabel=True, style='solid', linewidth=2.0)
mpl.contour(y, x, solver_L1.predicted(), (50,50), nlevels, interp=True, color='b', label='Predicted', 
            clabel=True, style='dashed', linewidth=2.0)
mpl.legend(loc='best', shadow=True, prop={'size':16})
mpl.xlabel('y (km)', fontsize = 16)
mpl.ylabel('x (km)', fontsize = 16)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.savefig('datafit.png', dpi=600)
#Image(filename='datafit.png')

# %% [markdown]
# ### The quality of the estimated magnetization direction can be accessed by performing a reduction to the pole (RTP). If the estimated magnetization direction is close to the true one, the RTP produces a magnetic anomaly predominantly positive over the magnetic source. In this numerical test, we analyze the estimated magnetization direction obtained by the robust (L1-norm) approach. This is done by performing a RTP via the [Polynomial Equivalent Layer](http://dx.doi.org/10.1190/geo2012-0196.1) (PEL) technique.

# %%
# Estimated inclination and declination with 
# the L1-norm approach
incs_L1 = solver_L1.estimate_[0][1]
decs_L1 = solver_L1.estimate_[0][2]

# %%
# Reduce the anomaly to the pole by using the
# Polynomial Equivalent Layer (PEL) technique

# Setup the layer
layer = mesher.PointGrid(area, z0+300.0, shape)

# Estimate the density using the PEL
windows = (20, 20)
degree = 1
misfit = PELTotalField(x, y, z, tf, inc, dec, layer, windows, degree, 
                       sinc=incs_L1, sdec=decs_L1)
# Here, only the smoothness regularization is used
regul = PELSmoothness(layer, windows, degree)
# Use an L-curve analysis to find the best regularization parameter
solver = LCurve(misfit, regul, [10 ** i for i in range(-20, -10)]).fit()
layer.addprop('magnetization', solver.estimate_)
residuals = solver.residuals()

# %%
print "Residuals between the NCTFA and the TFA \n produced by the PEL:"
print "mean: %.5f nT" % residuals.mean()
print "stddev: %.5f nT" % residuals.std()
# Out:
# Residuals between the NCTFA and the TFA
#  produced by the PEL:
# mean: -1.24280 nT
# stddev: 2.57447 nT

# %%
# Check the reduced-to-the-pole anomaly against the true one
tfpole  = polyprism.tf(x, y, z, modelpole, -90, 0) + \
          prism.tf(x, y, z, basement, -90, 0) # true
tfreduced = sphere.tf(x, y, z, layer, -90, 0) # reduced

# %%
# Plot the LCurve used for choosing the regularizing
# parameter in PEL

mpl.close('all')

mpl.figure(figsize=(8, 8))
mpl.suptitle('L-curve', fontsize=20)
mpl.title("Estimated regularization parameter: %g" % (solver.regul_param_),
          fontsize=16)
solver.plot_lcurve()
mpl.grid()
mpl.xlabel('Data misfit', fontsize=18)
mpl.ylabel('Regularization', fontsize=18)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.savefig('LCurve-PEL.png', dpi=600)
#Image(filename='LCurve-PEL.png')

# %% [markdown]
# ### Data misfit obtained via PEL

# %%
mpl.figure(figsize=(15, 5),  tight_layout = True)
mpl.subplot(1, 2, 1)
mpl.axis('scaled')
mpl.title('Data misfit (nT)', fontsize=20)
levels = mpl.contour(y, x, tf, shape, 15, color='r',
                     label='NCTFA', linewidth=2.0)
mpl.contour(y, x, solver.predicted(), shape, levels, color='k',
            style='dashed', label='PEL TFA', linewidth=2.0)
mpl.xlabel('y (km)', fontsize = 16)
mpl.ylabel('x (km)', fontsize = 16)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.legend(loc='best', fontsize=16)
mpl.m2km()
mpl.subplot(1, 2, 2)
mpl.title('Residuals (nT)', fontsize=20)
mpl.xticks(fontsize=16)
mpl.yticks(fontsize=16)
mpl.hist(residuals, bins=10)
mpl.savefig('PELfit.png', dpi=600)
#Image(filename='PELfit.png')

# %% [markdown]
# ### Plot the reduced-to-the-pole anomaly

# %%
lmin = np.floor(np.min([tfpole, tfreduced]))
lmin -= lmin%10
lmax = np.ceil(np.max([tfpole, tfreduced]))
lmax += lmax%10
dl = 20.0
levels = np.arange(lmin, lmax+dl, dl)

mpl.figure(figsize=(18, 5))
mpl.subplot(1, 3, 1)
mpl.axis('scaled')
mpl.title('True (nT)', fontsize=16)
mpl.contourf(y, x, tfpole, shape, levels, interp=True)
mpl.colorbar(shrink=0.75)
mpl.xlabel('y (km)', fontsize = 14)
mpl.ylabel('x (km)', fontsize = 14)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.subplot(1, 3, 2)
mpl.axis('scaled')
mpl.title('Reduced (nT)', fontsize=16)
mpl.contourf(y, x, tfreduced, shape, levels, interp=True)
mpl.colorbar(shrink=0.75)
mpl.xlabel('y (km)', fontsize = 14)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.subplot(1, 3, 3)
mpl.title('True - Reduced (nT)', fontsize=16)
mpl.axis('scaled')
mpl.pcolor(y, x, tfpole - tfreduced, shape)
mpl.colorbar(shrink=0.75)
mpl.xlabel('y (km)', fontsize = 14)
mpl.xticks(fontsize=14)
mpl.yticks(fontsize=14)
mpl.m2km()
mpl.savefig('RTP.png', dpi=600)
#Image(filename='RTP.png')
